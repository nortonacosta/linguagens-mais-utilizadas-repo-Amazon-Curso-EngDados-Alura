# %% [markdown]
# # Concedendo Requests

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# # Extraindo dados

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
username = 'amzn'
url = f'{api_base_url}/users/{username}/followers'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/followers'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
followers = response.json()

# %%
len(followers)
# Out:
# 30

# %% [markdown]
# # Autenticação da API do GitHub

# %%
access_token = 'Seu Token' # Token Github 
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# # Paginando lista de seguidores

# %%
page = 1
followers_list = []

# %%
while True:
    #faz a requisição
    url_page = f'{url}?page={page}'
    response = requests.get(url_page, headers=headers)

    # Verifica o status da resposta
    if response.status_code != 200:
        print(f"Erro na requisição: {response.status_code}")
        break

    #Converte a resposta para um objeto JSON
    try:
        followers = response.json()
    except ValueError:
        print("Erro ao converter a resposta para JSON")
        break

    # Imprime informações de depuração
    #print(f"Página: {page}, Número de seguidores recebidos: {len(followers)}")


    # Caso a lista esteja vazia, podemos sair do laço pois todos os dados foram extraídos
    if len(followers) == 0:        
        break
    
    # Adiciona os seguidores à lista
    followers_list.extend(followers)
    
    # Incrementa o valor de 'page' para a próxima requisição
    page += 1

# %%
total_pages = page - 1
total_followers = len(followers_list)

# %%
total_pages
# Out:
# 48

# %%
total_followers
# Out:
# 1431

# %%
followers_list
# Out:
# [{'login': 'tkersey',
#   'id': 217,
#   'node_id': 'MDQ6VXNlcjIxNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/217?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tkersey',
#   'html_url': 'https://github.com/tkersey',
#   'followers_url': 'https://api.github.com/users/tkersey/followers',
#   'following_url': 'https://api.github.com/users/tkersey/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/tkersey/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/tkersey/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/tkersey/subscriptions',
#   'organizations_url': 'https://api.github.com/users/tkersey/orgs',
#   'repos_url': 'https://api.github.com/users/tkersey/repos',
#   'events_url': 'https://api.github.com/users/tkersey/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/tkersey/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'njonsson',
#   'id': 645,
#   'node_id': 'MDQ6VXNlcjY0NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/645?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/njonsson',
#   'html_url': 'https://github.com/njonsson',
#   'followers_url': 'https://api.github.com/users/njonsson/followers',
#   'following_url': 'https://api.github.com/users/njonsson/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/njonsson/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/njonsson/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/njonsson/subscriptions',
#   'organizations_url': 'https://api.github.com/users/njonsson/orgs',
#   'repos_url': 'https://api.github.com/users/njonsson/repos',
#   'events_url': 'https://api.github.com/users/njonsson/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/njonsson/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'bangpound',
#   'id': 6731,
#   'node_id': 'MDQ6VXNlcjY3MzE=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6731?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bangpound',
#   'html_url': 'https://github.com/bangpound',
#   'followers_url': 'https://api.github.com/users/bangpound/followers',
#   'following_url': 'https://api.github.com/users/bangpound/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bangpound/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/bangpound/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bangpound/subscriptions',
#   'organizations_url': 'https://api.github.com/users/bangpound/orgs',
#   'repos_url': 'https://api.github.com/users/bangpound/repos',
#   'events_url': 'https://api.github.com/users/bangpound/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/bangpound/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'koconder',
#   'id': 25068,
#   'node_id': 'MDQ6VXNlcjI1MDY4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/25068?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/koconder',
#   'html_url': 'https://github.com/koconder',
#   'followers_url': 'https://api.github.com/users/koconder/followers',
#   'following_url': 'https://api.github.com/users/koconder/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/koconder/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/koconder/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/koconder/subscriptions',
#   'organizations_url': 'https://api.github.com/users/koconder/orgs',
#   'repos_url': 'https://api.github.com/users/koconder/repos',
#   'events_url': 'https://api.github.com/users/koconder/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/koconder/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Rud5G',
#   'id': 27158,
#   'node_id': 'MDQ6VXNlcjI3MTU4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/27158?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Rud5G',
#   'html_url': 'https://github.com/Rud5G',
#   'followers_url': 'https://api.github.com/users/Rud5G/followers',
#   'following_url': 'https://api.github.com/users/Rud5G/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Rud5G/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Rud5G/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Rud5G/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Rud5G/orgs',
#   'repos_url': 'https://api.github.com/users/Rud5G/repos',
#   'events_url': 'https://api.github.com/users/Rud5G/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Rud5G/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mlsj1',
#   'id': 29375,
#   'node_id': 'MDQ6VXNlcjI5Mzc1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/29375?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mlsj1',
#   'html_url': 'https://github.com/mlsj1',
#   'followers_url': 'https://api.github.com/users/mlsj1/followers',
#   'following_url': 'https://api.github.com/users/mlsj1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mlsj1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mlsj1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mlsj1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mlsj1/orgs',
#   'repos_url': 'https://api.github.com/users/mlsj1/repos',
#   'events_url': 'https://api.github.com/users/mlsj1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mlsj1/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'syug',
#   'id': 39264,
#   'node_id': 'MDQ6VXNlcjM5MjY0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/39264?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/syug',
#   'html_url': 'https://github.com/syug',
#   'followers_url': 'https://api.github.com/users/syug/followers',
#   'following_url': 'https://api.github.com/users/syug/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/syug/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/syug/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/syug/subscriptions',
#   'organizations_url': 'https://api.github.com/users/syug/orgs',
#   'repos_url': 'https://api.github.com/users/syug/repos',
#   'events_url': 'https://api.github.com/users/syug/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/syug/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'esneko',
#   'id': 64329,
#   'node_id': 'MDQ6VXNlcjY0MzI5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/64329?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/esneko',
#   'html_url': 'https://github.com/esneko',
#   'followers_url': 'https://api.github.com/users/esneko/followers',
#   'following_url': 'https://api.github.com/users/esneko/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/esneko/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/esneko/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/esneko/subscriptions',
#   'organizations_url': 'https://api.github.com/users/esneko/orgs',
#   'repos_url': 'https://api.github.com/users/esneko/repos',
#   'events_url': 'https://api.github.com/users/esneko/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/esneko/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'neopunisher',
#   'id': 73310,
#   'node_id': 'MDQ6VXNlcjczMzEw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/73310?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/neopunisher',
#   'html_url': 'https://github.com/neopunisher',
#   'followers_url': 'https://api.github.com/users/neopunisher/followers',
#   'following_url': 'https://api.github.com/users/neopunisher/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/neopunisher/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/neopunisher/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/neopunisher/subscriptions',
#   'organizations_url': 'https://api.github.com/users/neopunisher/orgs',
#   'repos_url': 'https://api.github.com/users/neopunisher/repos',
#   'events_url': 'https://api.github.com/users/neopunisher/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/neopunisher/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'jazzwang',
#   'id': 76903,
#   'node_id': 'MDQ6VXNlcjc2OTAz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/76903?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jazzwang',
#   'html_url': 'https://github.com/jazzwang',
#   'followers_url': 'https://api.github.com/users/jazzwang/followers',
#   'following_url': 'https://api.github.com/users/jazzwang/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/jazzwang/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/jazzwang/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/jazzwang/subscriptions',
#   'organizations_url': 'https://api.github.com/users/jazzwang/orgs',
#   'repos_url': 'https://api.github.com/users/jazzwang/repos',
#   'events_url': 'https://api.github.com/users/jazzwang/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/jazzwang/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'begoon',
#   'id': 84461,
#   'node_id': 'MDQ6VXNlcjg0NDYx',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/84461?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/begoon',
#   'html_url': 'https://github.com/begoon',
#   'followers_url': 'https://api.github.com/users/begoon/followers',
#   'following_url': 'https://api.github.com/users/begoon/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/begoon/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/begoon/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/begoon/subscriptions',
#   'organizations_url': 'https://api.github.com/users/begoon/orgs',
#   'repos_url': 'https://api.github.com/users/begoon/repos',
#   'events_url': 'https://api.github.com/users/begoon/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/begoon/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'fly51fly',
#   'id': 128885,
#   'node_id': 'MDQ6VXNlcjEyODg4NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/128885?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fly51fly',
#   'html_url': 'https://github.com/fly51fly',
#   'followers_url': 'https://api.github.com/users/fly51fly/followers',
#   'following_url': 'https://api.github.com/users/fly51fly/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/fly51fly/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/fly51fly/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/fly51fly/subscriptions',
#   'organizations_url': 'https://api.github.com/users/fly51fly/orgs',
#   'repos_url': 'https://api.github.com/users/fly51fly/repos',
#   'events_url': 'https://api.github.com/users/fly51fly/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/fly51fly/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'fallenpegasus',
#   'id': 130612,
#   'node_id': 'MDQ6VXNlcjEzMDYxMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/130612?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fallenpegasus',
#   'html_url': 'https://github.com/fallenpegasus',
#   'followers_url': 'https://api.github.com/users/fallenpegasus/followers',
#   'following_url': 'https://api.github.com/users/fallenpegasus/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/fallenpegasus/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/fallenpegasus/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/fallenpegasus/subscriptions',
#   'organizations_url': 'https://api.github.com/users/fallenpegasus/orgs',
#   'repos_url': 'https://api.github.com/users/fallenpegasus/repos',
#   'events_url': 'https://api.github.com/users/fallenpegasus/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/fallenpegasus/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'fribeiro1',
#   'id': 148002,
#   'node_id': 'MDQ6VXNlcjE0ODAwMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/148002?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fribeiro1',
#   'html_url': 'https://github.com/fribeiro1',
#   'followers_url': 'https://api.github.com/users/fribeiro1/followers',
#   'following_url': 'https://api.github.com/users/fribeiro1/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/fribeiro1/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/fribeiro1/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/fribeiro1/subscriptions',
#   'organizations_url': 'https://api.github.com/users/fribeiro1/orgs',
#   'repos_url': 'https://api.github.com/users/fribeiro1/repos',
#   'events_url': 'https://api.github.com/users/fribeiro1/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/fribeiro1/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'brase',
#   'id': 170088,
#   'node_id': 'MDQ6VXNlcjE3MDA4OA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/170088?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/brase',
#   'html_url': 'https://github.com/brase',
#   'followers_url': 'https://api.github.com/users/brase/followers',
#   'following_url': 'https://api.github.com/users/brase/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/brase/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/brase/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/brase/subscriptions',
#   'organizations_url': 'https://api.github.com/users/brase/orgs',
#   'repos_url': 'https://api.github.com/users/brase/repos',
#   'events_url': 'https://api.github.com/users/brase/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/brase/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'chchrist',
#   'id': 177884,
#   'node_id': 'MDQ6VXNlcjE3Nzg4NA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/177884?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chchrist',
#   'html_url': 'https://github.com/chchrist',
#   'followers_url': 'https://api.github.com/users/chchrist/followers',
#   'following_url': 'https://api.github.com/users/chchrist/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/chchrist/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/chchrist/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/chchrist/subscriptions',
#   'organizations_url': 'https://api.github.com/users/chchrist/orgs',
#   'repos_url': 'https://api.github.com/users/chchrist/repos',
#   'events_url': 'https://api.github.com/users/chchrist/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/chchrist/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'massimoselvi',
#   'id': 200969,
#   'node_id': 'MDQ6VXNlcjIwMDk2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/200969?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/massimoselvi',
#   'html_url': 'https://github.com/massimoselvi',
#   'followers_url': 'https://api.github.com/users/massimoselvi/followers',
#   'following_url': 'https://api.github.com/users/massimoselvi/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/massimoselvi/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/massimoselvi/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/massimoselvi/subscriptions',
#   'organizations_url': 'https://api.github.com/users/massimoselvi/orgs',
#   'repos_url': 'https://api.github.com/users/massimoselvi/repos',
#   'events_url': 'https://api.github.com/users/massimoselvi/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/massimoselvi/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ScottJWalter',
#   'id': 205537,
#   'node_id': 'MDQ6VXNlcjIwNTUzNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/205537?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ScottJWalter',
#   'html_url': 'https://github.com/ScottJWalter',
#   'followers_url': 'https://api.github.com/users/ScottJWalter/followers',
#   'following_url': 'https://api.github.com/users/ScottJWalter/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ScottJWalter/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ScottJWalter/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ScottJWalter/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ScottJWalter/orgs',
#   'repos_url': 'https://api.github.com/users/ScottJWalter/repos',
#   'events_url': 'https://api.github.com/users/ScottJWalter/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ScottJWalter/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'adeelahmad',
#   'id': 230291,
#   'node_id': 'MDQ6VXNlcjIzMDI5MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/230291?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/adeelahmad',
#   'html_url': 'https://github.com/adeelahmad',
#   'followers_url': 'https://api.github.com/users/adeelahmad/followers',
#   'following_url': 'https://api.github.com/users/adeelahmad/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/adeelahmad/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/adeelahmad/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/adeelahmad/subscriptions',
#   'organizations_url': 'https://api.github.com/users/adeelahmad/orgs',
#   'repos_url': 'https://api.github.com/users/adeelahmad/repos',
#   'events_url': 'https://api.github.com/users/adeelahmad/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/adeelahmad/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mindcrime',
#   'id': 231338,
#   'node_id': 'MDQ6VXNlcjIzMTMzOA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/231338?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mindcrime',
#   'html_url': 'https://github.com/mindcrime',
#   'followers_url': 'https://api.github.com/users/mindcrime/followers',
#   'following_url': 'https://api.github.com/users/mindcrime/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mindcrime/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mindcrime/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mindcrime/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mindcrime/orgs',
#   'repos_url': 'https://api.github.com/users/mindcrime/repos',
#   'events_url': 'https://api.github.com/users/mindcrime/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mindcrime/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'informaticadiaz',
#   'id': 240744,
#   'node_id': 'MDQ6VXNlcjI0MDc0NA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/240744?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/informaticadiaz',
#   'html_url': 'https://github.com/informaticadiaz',
#   'followers_url': 'https://api.github.com/users/informaticadiaz/followers',
#   'following_url': 'https://api.github.com/users/informaticadiaz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/informaticadiaz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/informaticadiaz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/informaticadiaz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/informaticadiaz/orgs',
#   'repos_url': 'https://api.github.com/users/informaticadiaz/repos',
#   'events_url': 'https://api.github.com/users/informaticadiaz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/informaticadiaz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'MarceloNascimento',
#   'id': 251708,
#   'node_id': 'MDQ6VXNlcjI1MTcwOA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/251708?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MarceloNascimento',
#   'html_url': 'https://github.com/MarceloNascimento',
#   'followers_url': 'https://api.github.com/users/MarceloNascimento/followers',
#   'following_url': 'https://api.github.com/users/MarceloNascimento/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/MarceloNascimento/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/MarceloNascimento/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/MarceloNascimento/subscriptions',
#   'organizations_url': 'https://api.github.com/users/MarceloNascimento/orgs',
#   'repos_url': 'https://api.github.com/users/MarceloNascimento/repos',
#   'events_url': 'https://api.github.com/users/MarceloNascimento/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/MarceloNascimento/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'dmsbilas',
#   'id': 280067,
#   'node_id': 'MDQ6VXNlcjI4MDA2Nw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/280067?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dmsbilas',
#   'html_url': 'https://github.com/dmsbilas',
#   'followers_url': 'https://api.github.com/users/dmsbilas/followers',
#   'following_url': 'https://api.github.com/users/dmsbilas/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dmsbilas/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dmsbilas/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dmsbilas/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dmsbilas/orgs',
#   'repos_url': 'https://api.github.com/users/dmsbilas/repos',
#   'events_url': 'https://api.github.com/users/dmsbilas/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dmsbilas/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'thimslugga',
#   'id': 285055,
#   'node_id': 'MDQ6VXNlcjI4NTA1NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/285055?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/thimslugga',
#   'html_url': 'https://github.com/thimslugga',
#   'followers_url': 'https://api.github.com/users/thimslugga/followers',
#   'following_url': 'https://api.github.com/users/thimslugga/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/thimslugga/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/thimslugga/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/thimslugga/subscriptions',
#   'organizations_url': 'https://api.github.com/users/thimslugga/orgs',
#   'repos_url': 'https://api.github.com/users/thimslugga/repos',
#   'events_url': 'https://api.github.com/users/thimslugga/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/thimslugga/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'leecardona',
#   'id': 333470,
#   'node_id': 'MDQ6VXNlcjMzMzQ3MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/333470?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/leecardona',
#   'html_url': 'https://github.com/leecardona',
#   'followers_url': 'https://api.github.com/users/leecardona/followers',
#   'following_url': 'https://api.github.com/users/leecardona/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/leecardona/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/leecardona/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/leecardona/subscriptions',
#   'organizations_url': 'https://api.github.com/users/leecardona/orgs',
#   'repos_url': 'https://api.github.com/users/leecardona/repos',
#   'events_url': 'https://api.github.com/users/leecardona/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/leecardona/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'shyuan',
#   'id': 347809,
#   'node_id': 'MDQ6VXNlcjM0NzgwOQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/347809?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/shyuan',
#   'html_url': 'https://github.com/shyuan',
#   'followers_url': 'https://api.github.com/users/shyuan/followers',
#   'following_url': 'https://api.github.com/users/shyuan/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/shyuan/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/shyuan/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/shyuan/subscriptions',
#   'organizations_url': 'https://api.github.com/users/shyuan/orgs',
#   'repos_url': 'https://api.github.com/users/shyuan/repos',
#   'events_url': 'https://api.github.com/users/shyuan/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/shyuan/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'nara',
#   'id': 357938,
#   'node_id': 'MDQ6VXNlcjM1NzkzOA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/357938?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nara',
#   'html_url': 'https://github.com/nara',
#   'followers_url': 'https://api.github.com/users/nara/followers',
#   'following_url': 'https://api.github.com/users/nara/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nara/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/nara/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nara/subscriptions',
#   'organizations_url': 'https://api.github.com/users/nara/orgs',
#   'repos_url': 'https://api.github.com/users/nara/repos',
#   'events_url': 'https://api.github.com/users/nara/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/nara/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'openam',
#   'id': 419983,
#   'node_id': 'MDQ6VXNlcjQxOTk4Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/419983?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/openam',
#   'html_url': 'https://github.com/openam',
#   'followers_url': 'https://api.github.com/users/openam/followers',
#   'following_url': 'https://api.github.com/users/openam/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/openam/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/openam/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/openam/subscriptions',
#   'organizations_url': 'https://api.github.com/users/openam/orgs',
#   'repos_url': 'https://api.github.com/users/openam/repos',
#   'events_url': 'https://api.github.com/users/openam/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/openam/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'semsphy',
#   'id': 423396,
#   'node_id': 'MDQ6VXNlcjQyMzM5Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/423396?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/semsphy',
#   'html_url': 'https://github.com/semsphy',
#   'followers_url': 'https://api.github.com/users/semsphy/followers',
#   'following_url': 'https://api.github.com/users/semsphy/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/semsphy/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/semsphy/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/semsphy/subscriptions',
#   'organizations_url': 'https://api.github.com/users/semsphy/orgs',
#   'repos_url': 'https://api.github.com/users/semsphy/repos',
#   'events_url': 'https://api.github.com/users/semsphy/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/semsphy/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'srp19',
#   'id': 433986,
#   'node_id': 'MDQ6VXNlcjQzMzk4Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/433986?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/srp19',
#   'html_url': 'https://github.com/srp19',
#   'followers_url': 'https://api.github.com/users/srp19/followers',
#   'following_url': 'https://api.github.com/users/srp19/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/srp19/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/srp19/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/srp19/subscriptions',
#   'organizations_url': 'https://api.github.com/users/srp19/orgs',
#   'repos_url': 'https://api.github.com/users/srp19/repos',
#   'events_url': 'https://api.github.com/users/srp19/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/srp19/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'DaemonCahill',
#   'id': 438181,
#   'node_id': 'MDQ6VXNlcjQzODE4MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/438181?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/DaemonCahill',
#   'html_url': 'https://github.com/DaemonCahill',
#   'followers_url': 'https://api.github.com/users/DaemonCahill/followers',
#   'following_url': 'https://api.github.com/users/DaemonCahill/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/DaemonCahill/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/DaemonCahill/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/DaemonCahill/subscriptions',
#   'organizations_url': 'https://api.github.com/users/DaemonCahill/orgs',
#   'repos_url': 'https://api.github.com/users/DaemonCahill/repos',
#   'events_url': 'https://api.github.com/users/DaemonCahill/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/DaemonCahill/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Cambera',
#   'id': 491091,
#   'node_id': 'MDQ6VXNlcjQ5MTA5MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/491091?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Cambera',
#   'html_url': 'https://github.com/Cambera',
#   'followers_url': 'https://api.github.com/users/Cambera/followers',
#   'following_url': 'https://api.github.com/users/Cambera/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Cambera/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Cambera/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Cambera/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Cambera/orgs',
#   'repos_url': 'https://api.github.com/users/Cambera/repos',
#   'events_url': 'https://api.github.com/users/Cambera/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Cambera/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'riyadparvez',
#   'id': 494783,
#   'node_id': 'MDQ6VXNlcjQ5NDc4Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/494783?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/riyadparvez',
#   'html_url': 'https://github.com/riyadparvez',
#   'followers_url': 'https://api.github.com/users/riyadparvez/followers',
#   'following_url': 'https://api.github.com/users/riyadparvez/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/riyadparvez/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/riyadparvez/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/riyadparvez/subscriptions',
#   'organizations_url': 'https://api.github.com/users/riyadparvez/orgs',
#   'repos_url': 'https://api.github.com/users/riyadparvez/repos',
#   'events_url': 'https://api.github.com/users/riyadparvez/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/riyadparvez/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'nattfodd',
#   'id': 540337,
#   'node_id': 'MDQ6VXNlcjU0MDMzNw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/540337?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nattfodd',
#   'html_url': 'https://github.com/nattfodd',
#   'followers_url': 'https://api.github.com/users/nattfodd/followers',
#   'following_url': 'https://api.github.com/users/nattfodd/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nattfodd/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/nattfodd/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nattfodd/subscriptions',
#   'organizations_url': 'https://api.github.com/users/nattfodd/orgs',
#   'repos_url': 'https://api.github.com/users/nattfodd/repos',
#   'events_url': 'https://api.github.com/users/nattfodd/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/nattfodd/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mitaka',
#   'id': 548822,
#   'node_id': 'MDQ6VXNlcjU0ODgyMg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/548822?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mitaka',
#   'html_url': 'https://github.com/mitaka',
#   'followers_url': 'https://api.github.com/users/mitaka/followers',
#   'following_url': 'https://api.github.com/users/mitaka/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mitaka/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mitaka/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mitaka/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mitaka/orgs',
#   'repos_url': 'https://api.github.com/users/mitaka/repos',
#   'events_url': 'https://api.github.com/users/mitaka/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mitaka/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ZhangYunfang',
#   'id': 586120,
#   'node_id': 'MDQ6VXNlcjU4NjEyMA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/586120?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ZhangYunfang',
#   'html_url': 'https://github.com/ZhangYunfang',
#   'followers_url': 'https://api.github.com/users/ZhangYunfang/followers',
#   'following_url': 'https://api.github.com/users/ZhangYunfang/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ZhangYunfang/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ZhangYunfang/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ZhangYunfang/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ZhangYunfang/orgs',
#   'repos_url': 'https://api.github.com/users/ZhangYunfang/repos',
#   'events_url': 'https://api.github.com/users/ZhangYunfang/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ZhangYunfang/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'temosy',
#   'id': 587726,
#   'node_id': 'MDQ6VXNlcjU4NzcyNg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/587726?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/temosy',
#   'html_url': 'https://github.com/temosy',
#   'followers_url': 'https://api.github.com/users/temosy/followers',
#   'following_url': 'https://api.github.com/users/temosy/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/temosy/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/temosy/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/temosy/subscriptions',
#   'organizations_url': 'https://api.github.com/users/temosy/orgs',
#   'repos_url': 'https://api.github.com/users/temosy/repos',
#   'events_url': 'https://api.github.com/users/temosy/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/temosy/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'threadstonesecure',
#   'id': 644476,
#   'node_id': 'MDQ6VXNlcjY0NDQ3Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/644476?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/threadstonesecure',
#   'html_url': 'https://github.com/threadstonesecure',
#   'followers_url': 'https://api.github.com/users/threadstonesecure/followers',
#   'following_url': 'https://api.github.com/users/threadstonesecure/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/threadstonesecure/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/threadstonesecure/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/threadstonesecure/subscriptions',
#   'organizations_url': 'https://api.github.com/users/threadstonesecure/orgs',
#   'repos_url': 'https://api.github.com/users/threadstonesecure/repos',
#   'events_url': 'https://api.github.com/users/threadstonesecure/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/threadstonesecure/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'manuelhunziker',
#   'id': 655369,
#   'node_id': 'MDQ6VXNlcjY1NTM2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/655369?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/manuelhunziker',
#   'html_url': 'https://github.com/manuelhunziker',
#   'followers_url': 'https://api.github.com/users/manuelhunziker/followers',
#   'following_url': 'https://api.github.com/users/manuelhunziker/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/manuelhunziker/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/manuelhunziker/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/manuelhunziker/subscriptions',
#   'organizations_url': 'https://api.github.com/users/manuelhunziker/orgs',
#   'repos_url': 'https://api.github.com/users/manuelhunziker/repos',
#   'events_url': 'https://api.github.com/users/manuelhunziker/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/manuelhunziker/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ambagasdowa',
#   'id': 661086,
#   'node_id': 'MDQ6VXNlcjY2MTA4Ng==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/661086?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ambagasdowa',
#   'html_url': 'https://github.com/ambagasdowa',
#   'followers_url': 'https://api.github.com/users/ambagasdowa/followers',
#   'following_url': 'https://api.github.com/users/ambagasdowa/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ambagasdowa/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ambagasdowa/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ambagasdowa/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ambagasdowa/orgs',
#   'repos_url': 'https://api.github.com/users/ambagasdowa/repos',
#   'events_url': 'https://api.github.com/users/ambagasdowa/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ambagasdowa/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'pedro-lima',
#   'id': 707395,
#   'node_id': 'MDQ6VXNlcjcwNzM5NQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/707395?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pedro-lima',
#   'html_url': 'https://github.com/pedro-lima',
#   'followers_url': 'https://api.github.com/users/pedro-lima/followers',
#   'following_url': 'https://api.github.com/users/pedro-lima/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pedro-lima/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pedro-lima/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pedro-lima/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pedro-lima/orgs',
#   'repos_url': 'https://api.github.com/users/pedro-lima/repos',
#   'events_url': 'https://api.github.com/users/pedro-lima/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/pedro-lima/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'alexharvey',
#   'id': 722253,
#   'node_id': 'MDQ6VXNlcjcyMjI1Mw==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/722253?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alexharvey',
#   'html_url': 'https://github.com/alexharvey',
#   'followers_url': 'https://api.github.com/users/alexharvey/followers',
#   'following_url': 'https://api.github.com/users/alexharvey/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/alexharvey/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/alexharvey/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/alexharvey/subscriptions',
#   'organizations_url': 'https://api.github.com/users/alexharvey/orgs',
#   'repos_url': 'https://api.github.com/users/alexharvey/repos',
#   'events_url': 'https://api.github.com/users/alexharvey/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/alexharvey/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'josh-fisher',
#   'id': 735570,
#   'node_id': 'MDQ6VXNlcjczNTU3MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/735570?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/josh-fisher',
#   'html_url': 'https://github.com/josh-fisher',
#   'followers_url': 'https://api.github.com/users/josh-fisher/followers',
#   'following_url': 'https://api.github.com/users/josh-fisher/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/josh-fisher/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/josh-fisher/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/josh-fisher/subscriptions',
#   'organizations_url': 'https://api.github.com/users/josh-fisher/orgs',
#   'repos_url': 'https://api.github.com/users/josh-fisher/repos',
#   'events_url': 'https://api.github.com/users/josh-fisher/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/josh-fisher/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'kumarlokesh',
#   'id': 742592,
#   'node_id': 'MDQ6VXNlcjc0MjU5Mg==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/742592?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kumarlokesh',
#   'html_url': 'https://github.com/kumarlokesh',
#   'followers_url': 'https://api.github.com/users/kumarlokesh/followers',
#   'following_url': 'https://api.github.com/users/kumarlokesh/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/kumarlokesh/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/kumarlokesh/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/kumarlokesh/subscriptions',
#   'organizations_url': 'https://api.github.com/users/kumarlokesh/orgs',
#   'repos_url': 'https://api.github.com/users/kumarlokesh/repos',
#   'events_url': 'https://api.github.com/users/kumarlokesh/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/kumarlokesh/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'subidit',
#   'id': 747151,
#   'node_id': 'MDQ6VXNlcjc0NzE1MQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/747151?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/subidit',
#   'html_url': 'https://github.com/subidit',
#   'followers_url': 'https://api.github.com/users/subidit/followers',
#   'following_url': 'https://api.github.com/users/subidit/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/subidit/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/subidit/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/subidit/subscriptions',
#   'organizations_url': 'https://api.github.com/users/subidit/orgs',
#   'repos_url': 'https://api.github.com/users/subidit/repos',
#   'events_url': 'https://api.github.com/users/subidit/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/subidit/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'pdevenraj',
#   'id': 761450,
#   'node_id': 'MDQ6VXNlcjc2MTQ1MA==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/761450?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pdevenraj',
#   'html_url': 'https://github.com/pdevenraj',
#   'followers_url': 'https://api.github.com/users/pdevenraj/followers',
#   'following_url': 'https://api.github.com/users/pdevenraj/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/pdevenraj/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/pdevenraj/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/pdevenraj/subscriptions',
#   'organizations_url': 'https://api.github.com/users/pdevenraj/orgs',
#   'repos_url': 'https://api.github.com/users/pdevenraj/repos',
#   'events_url': 'https://api.github.com/users/pdevenraj/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/pdevenraj/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'nerandell',
#   'id': 820105,
#   'node_id': 'MDQ6VXNlcjgyMDEwNQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/820105?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nerandell',
#   'html_url': 'https://github.com/nerandell',
#   'followers_url': 'https://api.github.com/users/nerandell/followers',
#   'following_url': 'https://api.github.com/users/nerandell/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/nerandell/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/nerandell/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/nerandell/subscriptions',
#   'organizations_url': 'https://api.github.com/users/nerandell/orgs',
#   'repos_url': 'https://api.github.com/users/nerandell/repos',
#   'events_url': 'https://api.github.com/users/nerandell/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/nerandell/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'raghuboosetty',
#   'id': 853315,
#   'node_id': 'MDQ6VXNlcjg1MzMxNQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/853315?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/raghuboosetty',
#   'html_url': 'https://github.com/raghuboosetty',
#   'followers_url': 'https://api.github.com/users/raghuboosetty/followers',
#   'following_url': 'https://api.github.com/users/raghuboosetty/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/raghuboosetty/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/raghuboosetty/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/raghuboosetty/subscriptions',
#   'organizations_url': 'https://api.github.com/users/raghuboosetty/orgs',
#   'repos_url': 'https://api.github.com/users/raghuboosetty/repos',
#   'events_url': 'https://api.github.com/users/raghuboosetty/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/raghuboosetty/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'tdmalone',
#   'id': 900469,
#   'node_id': 'MDQ6VXNlcjkwMDQ2OQ==',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/900469?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tdmalone',
#   'html_url': 'https://github.com/tdmalone',
#   'followers_url': 'https://api.github.com/users/tdmalone/followers',
#   'following_url': 'https://api.github.com/users/tdmalone/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/tdmalone/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/tdmalone/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/tdmalone/subscriptions',
# ...
#   'following_url': 'https://api.github.com/users/sanju50201/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sanju50201/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sanju50201/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sanju50201/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sanju50201/orgs',
#   'repos_url': 'https://api.github.com/users/sanju50201/repos',
#   'events_url': 'https://api.github.com/users/sanju50201/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sanju50201/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'marcusPrado02',
#   'id': 91127192,
#   'node_id': 'MDQ6VXNlcjkxMTI3MTky',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91127192?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/marcusPrado02',
#   'html_url': 'https://github.com/marcusPrado02',
#   'followers_url': 'https://api.github.com/users/marcusPrado02/followers',
#   'following_url': 'https://api.github.com/users/marcusPrado02/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/marcusPrado02/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/marcusPrado02/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/marcusPrado02/subscriptions',
#   'organizations_url': 'https://api.github.com/users/marcusPrado02/orgs',
#   'repos_url': 'https://api.github.com/users/marcusPrado02/repos',
#   'events_url': 'https://api.github.com/users/marcusPrado02/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/marcusPrado02/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Arshu200',
#   'id': 91214096,
#   'node_id': 'MDQ6VXNlcjkxMjE0MDk2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91214096?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Arshu200',
#   'html_url': 'https://github.com/Arshu200',
#   'followers_url': 'https://api.github.com/users/Arshu200/followers',
#   'following_url': 'https://api.github.com/users/Arshu200/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Arshu200/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Arshu200/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Arshu200/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Arshu200/orgs',
#   'repos_url': 'https://api.github.com/users/Arshu200/repos',
#   'events_url': 'https://api.github.com/users/Arshu200/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Arshu200/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'josephmartinmoran',
#   'id': 91217639,
#   'node_id': 'MDQ6VXNlcjkxMjE3NjM5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91217639?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/josephmartinmoran',
#   'html_url': 'https://github.com/josephmartinmoran',
#   'followers_url': 'https://api.github.com/users/josephmartinmoran/followers',
#   'following_url': 'https://api.github.com/users/josephmartinmoran/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/josephmartinmoran/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/josephmartinmoran/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/josephmartinmoran/subscriptions',
#   'organizations_url': 'https://api.github.com/users/josephmartinmoran/orgs',
#   'repos_url': 'https://api.github.com/users/josephmartinmoran/repos',
#   'events_url': 'https://api.github.com/users/josephmartinmoran/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/josephmartinmoran/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'AndreCoutinhom',
#   'id': 91290799,
#   'node_id': 'MDQ6VXNlcjkxMjkwNzk5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91290799?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/AndreCoutinhom',
#   'html_url': 'https://github.com/AndreCoutinhom',
#   'followers_url': 'https://api.github.com/users/AndreCoutinhom/followers',
#   'following_url': 'https://api.github.com/users/AndreCoutinhom/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/AndreCoutinhom/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/AndreCoutinhom/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/AndreCoutinhom/subscriptions',
#   'organizations_url': 'https://api.github.com/users/AndreCoutinhom/orgs',
#   'repos_url': 'https://api.github.com/users/AndreCoutinhom/repos',
#   'events_url': 'https://api.github.com/users/AndreCoutinhom/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/AndreCoutinhom/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'natamartins',
#   'id': 91438203,
#   'node_id': 'MDQ6VXNlcjkxNDM4MjAz',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91438203?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/natamartins',
#   'html_url': 'https://github.com/natamartins',
#   'followers_url': 'https://api.github.com/users/natamartins/followers',
#   'following_url': 'https://api.github.com/users/natamartins/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/natamartins/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/natamartins/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/natamartins/subscriptions',
#   'organizations_url': 'https://api.github.com/users/natamartins/orgs',
#   'repos_url': 'https://api.github.com/users/natamartins/repos',
#   'events_url': 'https://api.github.com/users/natamartins/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/natamartins/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'elcnu986',
#   'id': 91621147,
#   'node_id': 'U_kgDOBXYHGw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91621147?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/elcnu986',
#   'html_url': 'https://github.com/elcnu986',
#   'followers_url': 'https://api.github.com/users/elcnu986/followers',
#   'following_url': 'https://api.github.com/users/elcnu986/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/elcnu986/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/elcnu986/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/elcnu986/subscriptions',
#   'organizations_url': 'https://api.github.com/users/elcnu986/orgs',
#   'repos_url': 'https://api.github.com/users/elcnu986/repos',
#   'events_url': 'https://api.github.com/users/elcnu986/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/elcnu986/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'sssamm29',
#   'id': 91818594,
#   'node_id': 'U_kgDOBXkKYg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91818594?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sssamm29',
#   'html_url': 'https://github.com/sssamm29',
#   'followers_url': 'https://api.github.com/users/sssamm29/followers',
#   'following_url': 'https://api.github.com/users/sssamm29/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sssamm29/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/sssamm29/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sssamm29/subscriptions',
#   'organizations_url': 'https://api.github.com/users/sssamm29/orgs',
#   'repos_url': 'https://api.github.com/users/sssamm29/repos',
#   'events_url': 'https://api.github.com/users/sssamm29/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/sssamm29/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'techprogo',
#   'id': 91996410,
#   'node_id': 'U_kgDOBXvA-g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91996410?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/techprogo',
#   'html_url': 'https://github.com/techprogo',
#   'followers_url': 'https://api.github.com/users/techprogo/followers',
#   'following_url': 'https://api.github.com/users/techprogo/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/techprogo/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/techprogo/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/techprogo/subscriptions',
#   'organizations_url': 'https://api.github.com/users/techprogo/orgs',
#   'repos_url': 'https://api.github.com/users/techprogo/repos',
#   'events_url': 'https://api.github.com/users/techprogo/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/techprogo/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'mgaspirc',
#   'id': 92071928,
#   'node_id': 'U_kgDOBXzn-A',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92071928?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mgaspirc',
#   'html_url': 'https://github.com/mgaspirc',
#   'followers_url': 'https://api.github.com/users/mgaspirc/followers',
#   'following_url': 'https://api.github.com/users/mgaspirc/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/mgaspirc/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/mgaspirc/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/mgaspirc/subscriptions',
#   'organizations_url': 'https://api.github.com/users/mgaspirc/orgs',
#   'repos_url': 'https://api.github.com/users/mgaspirc/repos',
#   'events_url': 'https://api.github.com/users/mgaspirc/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/mgaspirc/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'SarfarajRahmn',
#   'id': 92102441,
#   'node_id': 'U_kgDOBX1fKQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92102441?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/SarfarajRahmn',
#   'html_url': 'https://github.com/SarfarajRahmn',
#   'followers_url': 'https://api.github.com/users/SarfarajRahmn/followers',
#   'following_url': 'https://api.github.com/users/SarfarajRahmn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/SarfarajRahmn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/SarfarajRahmn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/SarfarajRahmn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/SarfarajRahmn/orgs',
#   'repos_url': 'https://api.github.com/users/SarfarajRahmn/repos',
#   'events_url': 'https://api.github.com/users/SarfarajRahmn/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/SarfarajRahmn/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Aniketchaudhary16',
#   'id': 92148087,
#   'node_id': 'U_kgDOBX4Rdw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92148087?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Aniketchaudhary16',
#   'html_url': 'https://github.com/Aniketchaudhary16',
#   'followers_url': 'https://api.github.com/users/Aniketchaudhary16/followers',
#   'following_url': 'https://api.github.com/users/Aniketchaudhary16/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Aniketchaudhary16/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Aniketchaudhary16/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Aniketchaudhary16/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Aniketchaudhary16/orgs',
#   'repos_url': 'https://api.github.com/users/Aniketchaudhary16/repos',
#   'events_url': 'https://api.github.com/users/Aniketchaudhary16/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Aniketchaudhary16/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'JeromeXapix',
#   'id': 92473647,
#   'node_id': 'U_kgDOBYMJLw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92473647?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/JeromeXapix',
#   'html_url': 'https://github.com/JeromeXapix',
#   'followers_url': 'https://api.github.com/users/JeromeXapix/followers',
#   'following_url': 'https://api.github.com/users/JeromeXapix/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/JeromeXapix/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/JeromeXapix/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/JeromeXapix/subscriptions',
#   'organizations_url': 'https://api.github.com/users/JeromeXapix/orgs',
#   'repos_url': 'https://api.github.com/users/JeromeXapix/repos',
#   'events_url': 'https://api.github.com/users/JeromeXapix/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/JeromeXapix/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ClaudiaA18',
#   'id': 92523885,
#   'node_id': 'U_kgDOBYPNbQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92523885?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ClaudiaA18',
#   'html_url': 'https://github.com/ClaudiaA18',
#   'followers_url': 'https://api.github.com/users/ClaudiaA18/followers',
#   'following_url': 'https://api.github.com/users/ClaudiaA18/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ClaudiaA18/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ClaudiaA18/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ClaudiaA18/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ClaudiaA18/orgs',
#   'repos_url': 'https://api.github.com/users/ClaudiaA18/repos',
#   'events_url': 'https://api.github.com/users/ClaudiaA18/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ClaudiaA18/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'ElizabethJoseph25',
#   'id': 92835477,
#   'node_id': 'U_kgDOBYiOlQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92835477?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ElizabethJoseph25',
#   'html_url': 'https://github.com/ElizabethJoseph25',
#   'followers_url': 'https://api.github.com/users/ElizabethJoseph25/followers',
#   'following_url': 'https://api.github.com/users/ElizabethJoseph25/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ElizabethJoseph25/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ElizabethJoseph25/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ElizabethJoseph25/subscriptions',
#   'organizations_url': 'https://api.github.com/users/ElizabethJoseph25/orgs',
#   'repos_url': 'https://api.github.com/users/ElizabethJoseph25/repos',
#   'events_url': 'https://api.github.com/users/ElizabethJoseph25/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/ElizabethJoseph25/received_events',
#   'type': 'User',
#   'site_admin': False},
#  {'login': 'Manbendra2014',
#   'id': 92919625,
#   'node_id': 'U_kgDOBYnXSQ',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92919625?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Manbendra2014',
#   'html_url': 'https://github.com/Manbendra2014',
#   'followers_url': 'https://api.github.com/users/Manbendra2014/followers',
#   'following_url': 'https://api.github.com/users/Manbendra2014/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/Manbendra2014/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/Manbendra2014/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/Manbendra2014/subscriptions',
#   'organizations_url': 'https://api.github.com/users/Manbendra2014/orgs',
#   'repos_url': 'https://api.github.com/users/Manbendra2014/repos',
#   'events_url': 'https://api.github.com/users/Manbendra2014/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/Manbendra2014/received_events',
#   'type': 'User',
#   'site_admin': False},
#  ...]

# %%
followers_list[0]['login']
# Out:
# 'tkersey'

# %% [markdown]
# ### Percorrendo toda a lista(paginas) e salvar os nomes numa lista

# %%
# followers_name = []
# for follower in followers_list:
#      followers_name.append(follower['login'])
followers_name = [user['login'] for user in followers_list if 'login' in user] #List Comprehension

# %%
followers_name[:10]
# Out:
# ['tkersey',
#  'njonsson',
#  'bangpound',
#  'koconder',
#  'Rud5G',
#  'mlsj1',
#  'syug',
#  'esneko',
#  'neopunisher',
#  'jazzwang']
